# %%
# !/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
# Out:
# ==> Checking for `sudo` access (which may request your password)...
# ==> This script will install:
# /home/linuxbrew/.linuxbrew/bin/brew
# /home/linuxbrew/.linuxbrew/share/doc/homebrew
# /home/linuxbrew/.linuxbrew/share/man/man1/brew.1
# /home/linuxbrew/.linuxbrew/share/zsh/site-functions/_brew
# /home/linuxbrew/.linuxbrew/etc/bash_completion.d/brew
# /home/linuxbrew/.linuxbrew/Homebrew
# ==> The following new directories will be created:
# /home/linuxbrew/.linuxbrew/bin
# /home/linuxbrew/.linuxbrew/etc
# /home/linuxbrew/.linuxbrew/include
# /home/linuxbrew/.linuxbrew/lib
# /home/linuxbrew/.linuxbrew/sbin
# /home/linuxbrew/.linuxbrew/share
# /home/linuxbrew/.linuxbrew/var
# /home/linuxbrew/.linuxbrew/opt
# /home/linuxbrew/.linuxbrew/share/zsh
# /home/linuxbrew/.linuxbrew/share/zsh/site-functions
# /home/linuxbrew/.linuxbrew/var/homebrew
# /home/linuxbrew/.linuxbrew/var/homebrew/linked
# /home/linuxbrew/.linuxbrew/Cellar
# /home/linuxbrew/.linuxbrew/Caskroom
# /home/linuxbrew/.linuxbrew/Frameworks
#
# Press RETURN/ENTER to continue or any other key to abort:
# ==> /usr/bin/install -d -o root -g root -m 0755 /home/linuxbrew/.linuxbrew
# ==> /bin/mkdir -p /home/linuxbrew/.linuxbrew/bin /home/linuxbrew/.linuxbrew/etc /home/linuxbrew/.linuxbrew/include /home/linuxbrew/.linuxbrew/lib /home/linuxbrew/.linuxbrew/sbin /home/linuxbrew/.linuxbrew/share /home/linuxbrew/.linuxbrew/var /home/linuxbrew/.linuxbrew/opt /home/linuxbrew/.linuxbrew/share/zsh /home/linuxbrew/.linuxbrew/share/zsh/site-functions /home/linuxbrew/.linuxbrew/var/homebrew /home/linuxbrew/.linuxbrew/var/homebrew/linked /home/linuxbrew/.linuxbrew/Cellar /home/linuxbrew/.linuxbrew/Caskroom /home/linuxbrew/.linuxbrew/Frameworks
# ==> /bin/chmod ug=rwx /home/linuxbrew/.linuxbrew/bin /home/linuxbrew/.linuxbrew/etc /home/linuxbrew/.linuxbrew/include /home/linuxbrew/.linuxbrew/lib /home/linuxbrew/.linuxbrew/sbin /home/linuxbrew/.linuxbrew/share /home/linuxbrew/.linuxbrew/var /home/linuxbrew/.linuxbrew/opt /home/linuxbrew/.linuxbrew/share/zsh /home/linuxbrew/.linuxbrew/share/zsh/site-functions /home/linuxbrew/.linuxbrew/var/homebrew /home/linuxbrew/.linuxbrew/var/homebrew/linked /home/linuxbrew/.linuxbrew/Cellar /home/linuxbrew/.linuxbrew/Caskroom /home/linuxbrew/.linuxbrew/Frameworks
# ==> /bin/chmod go-w /home/linuxbrew/.linuxbrew/share/zsh /home/linuxbrew/.linuxbrew/share/zsh/site-functions
# ==> /bin/chown root /home/linuxbrew/.linuxbrew/bin /home/linuxbrew/.linuxbrew/etc /home/linuxbrew/.linuxbrew/include /home/linuxbrew/.linuxbrew/lib /home/linuxbrew/.linuxbrew/sbin /home/linuxbrew/.linuxbrew/share /home/linuxbrew/.linuxbrew/var /home/linuxbrew/.linuxbrew/opt /home/linuxbrew/.linuxbrew/share/zsh /home/linuxbrew/.linuxbrew/share/zsh/site-functions /home/linuxbrew/.linuxbrew/var/homebrew /home/linuxbrew/.linuxbrew/var/homebrew/linked /home/linuxbrew/.linuxbrew/Cellar /home/linuxbrew/.linuxbrew/Caskroom /home/linuxbrew/.linuxbrew/Frameworks
# ==> /bin/chgrp root /home/linuxbrew/.linuxbrew/bin /home/linuxbrew/.linuxbrew/etc /home/linuxbrew/.linuxbrew/include /home/linuxbrew/.linuxbrew/lib /home/linuxbrew/.linuxbrew/sbin /home/linuxbrew/.linuxbrew/share /home/linuxbrew/.linuxbrew/var /home/linuxbrew/.linuxbrew/opt /home/linuxbrew/.linuxbrew/share/zsh /home/linuxbrew/.linuxbrew/share/zsh/site-functions /home/linuxbrew/.linuxbrew/var/homebrew /home/linuxbrew/.linuxbrew/var/homebrew/linked /home/linuxbrew/.linuxbrew/Cellar /home/linuxbrew/.linuxbrew/Caskroom /home/linuxbrew/.linuxbrew/Frameworks
# ==> /bin/mkdir -p /home/linuxbrew/.linuxbrew/Homebrew
# ==> /bin/chown -R root:root /home/linuxbrew/.linuxbrew/Homebrew
# ==> Downloading and installing Homebrew...
# remote: Enumerating objects: 330761, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 330761 (delta 157), reused 160 (delta 111), pack-reused 330517 (from 3)
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Total 55 (delta 33), reused 33 (delta 33), pack-reused 22 (from 1)
# ==> Updating Homebrew...
# ==> Downloading https://ghcr.io/v2/homebrew/core/portable-ruby/blobs/sha256:cb96f8003dc6afae036adeaf892578fbc34eb11bbb5660dca7213677fa1047e8
# ######################################################################## 100.0%
# ==> Pouring portable-ruby-4.0.3.x86_64_linux.bottle.tar.gz
# Warning: /home/linuxbrew/.linuxbrew/bin is not in your PATH.
#   Instructions on how to configure your shell for Homebrew
#   can be found in the 'Next steps' section below.
# ==> Installation successful!
#
# ==> Homebrew has enabled anonymous aggregate formulae and cask analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics data has been sent yet (nor will any be during this install run).
#
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
#
# ==> Next steps:
# - Run these commands in your terminal to add Homebrew to your PATH:
#     echo >> /root/.bashrc
#     echo 'eval "$(/home/linuxbrew/.linuxbrew/bin/brew shellenv bash)"' >> /root/.bashrc
#     eval "$(/home/linuxbrew/.linuxbrew/bin/brew shellenv bash)"
# - Install Homebrew's dependencies if you have sudo access:
#     sudo apt-get install build-essential
#   For more information, see:
#     https://docs.brew.sh/Homebrew-on-Linux
# - We recommend that you install GCC:
#     brew install gcc
# - Run brew help to get started
# - Further documentation:
#     https://docs.brew.sh

# %%
import os
os.environ['PATH'] += ":/home/linuxbrew/.linuxbrew/bin"
# !eval $(/home/linuxbrew/.linuxbrew/bin/brew shellenv)

# %%
# !brew install llama.cpp
# Out:
# ==> Fetching downloads for: llama.cpp
# ✔︎ Bottle Manifest llama.cpp (8950)
# ✔︎ Bottle Manifest gmp (6.3.0)
# ✔︎ Bottle gmp (6.3.0)
# ✔︎ Bottle Manifest isl (0.27)
# ✔︎ Bottle Manifest mpfr (4.2.2)
# ✔︎ Bottle isl (0.27)
# ✔︎ Bottle mpfr (4.2.2)
# ✔︎ Bottle Manifest libmpc (1.4.1)
# ✔︎ Bottle Manifest lz4 (1.10.0)
# ✔︎ Bottle libmpc (1.4.1)
# ✔︎ Bottle Manifest xz (5.8.3)
# ✔︎ Bottle Manifest zlib-ng-compat (2.3.3_1)
# ✔︎ Bottle lz4 (1.10.0)
# ✔︎ Bottle xz (5.8.3)
# ✔︎ Bottle Manifest zstd (1.5.7_1)
# ✔︎ Bottle zlib-ng-compat (2.3.3_1)
# ✔︎ Bottle Manifest binutils (2.46.0)
# ✔︎ Bottle Manifest gcc (15.2.0_1)
# ✔︎ Bottle zstd (1.5.7_1)
# ✔︎ Bottle Manifest openblas (0.3.33)
# ✔︎ Bottle Manifest spirv-headers (1.4.341.0)
# ✔︎ Bottle spirv-headers (1.4.341.0)
# ✔︎ Bottle Manifest vulkan-headers (1.4.341.0)
# ✔︎ Bottle openblas (0.3.33)
# ✔︎ Bottle Manifest xorgproto (2025.1)
# ✔︎ Bottle vulkan-headers (1.4.341.0)
# ✔︎ Bottle xorgproto (2025.1)
# ✔︎ Bottle Manifest libxau (1.0.12)
# ✔︎ Bottle Manifest libxdmcp (1.1.5)
# ✔︎ Bottle libxau (1.0.12)
# ✔︎ Bottle libxdmcp (1.1.5)
# ✔︎ Bottle Manifest libxcb (1.17.0)
# ✔︎ Bottle Manifest libx11 (1.8.13)
# ✔︎ Bottle libx11 (1.8.13)
# ✔︎ Bottle libxcb (1.17.0)
# ✔︎ Bottle Manifest expat (2.8.0)
# ✔︎ Bottle expat (2.8.0)
# ✔︎ Bottle Manifest libffi (3.5.2)
# ✔︎ Bottle binutils (2.46.0)
# ✔︎ Bottle Manifest ncurses (6.6)
# ✔︎ Bottle libffi (3.5.2)
# ✔︎ Bottle Manifest readline (8.3.3)
# ✔︎ Bottle Manifest libxml2 (2.15.3)
# ✔︎ Bottle readline (8.3.3)
# ✔︎ Bottle ncurses (6.6)
# ✔︎ Bottle Manifest wayland (1.25.0)
# ✔︎ Bottle libxml2 (2.15.3)
# ✔︎ Bottle Manifest vulkan-loader (1.4.341.0)
# ✔︎ Bottle wayland (1.25.0)
# ✔︎ Bottle Manifest ggml (0.10.0)
# ✔︎ Bottle vulkan-loader (1.4.341.0)
# ✔︎ Bottle Manifest ca-certificates (2026-03-19)
# ✔︎ Bottle Manifest openssl@3 (3.6.2)
# ✔︎ Bottle ca-certificates (2026-03-19)
# ✔︎ Bottle llama.cpp (8950)
# ✔︎ Bottle ggml (0.10.0)
# ✔︎ Bottle openssl@3 (3.6.2)
# ✔︎ Bottle gcc (15.2.0_1)
# ==> Installing dependencies for llama.cpp: gmp, isl, mpfr, libmpc, lz4, xz, zlib-ng-compat, zstd, binutils, gcc, openblas, spirv-headers, vulkan-headers, xorgproto, libxau, libxdmcp, libxcb, libx11, expat, libffi, ncurses, readline, libxml2, wayland, vulkan-loader, ggml, ca-certificates and openssl@3
# ==> Installing llama.cpp dependency: gmp
# ==> Pouring gmp--6.3.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/gmp/6.3.0: 24 files, 4.1MB
# ==> Installing llama.cpp dependency: isl
# ==> Pouring isl--0.27.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/isl/0.27: 75 files, 10.3MB
# ==> Installing llama.cpp dependency: mpfr
# ==> Pouring mpfr--4.2.2.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/mpfr/4.2.2: 32 files, 4.2MB
# ==> Installing llama.cpp dependency: libmpc
# ==> Pouring libmpc--1.4.1.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libmpc/1.4.1: 15 files, 707.2KB
# ==> Installing llama.cpp dependency: lz4
# ==> Pouring lz4--1.10.0.x86_64_linux.bottle.1.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/lz4/1.10.0: 24 files, 817.9KB
# ==> Installing llama.cpp dependency: xz
# ==> Pouring xz--5.8.3.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/xz/5.8.3: 97 files, 2.8MB
# ==> Installing llama.cpp dependency: zlib-ng-compat
# ==> Pouring zlib-ng-compat--2.3.3_1.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/zlib-ng-compat/2.3.3_1: 17 files, 630.8KB
# ==> Installing llama.cpp dependency: zstd
# ==> Pouring zstd--1.5.7_1.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/zstd/1.5.7_1: 32 files, 3.2MB
# ==> Installing llama.cpp dependency: binutils
# ==> Pouring binutils--2.46.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/binutils/2.46.0: 6,289 files, 443.7MB
# ==> Installing llama.cpp dependency: gcc
# ==> Pouring gcc--15.2.0_1.x86_64_linux.bottle.tar.gz
# ==> Creating the GCC specs file: /home/linuxbrew/.linuxbrew/Cellar/gcc/15.2.0_1/bin/../lib/gcc/current/gcc/x86_64-pc-linux-gnu/15/specs
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/gcc/15.2.0_1: 2,175 files, 445.8MB
# ==> Installing llama.cpp dependency: openblas
# ==> Pouring openblas--0.3.33.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/openblas/0.3.33: 29 files, 108.4MB
# ==> Installing llama.cpp dependency: spirv-headers
# ==> Pouring spirv-headers--1.4.341.0.all.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/spirv-headers/1.4.341.0: 91 files, 3.7MB
# ==> Installing llama.cpp dependency: vulkan-headers
# ==> Pouring vulkan-headers--1.4.341.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/vulkan-headers/1.4.341.0: 71 files, 37.9MB
# ==> Installing llama.cpp dependency: xorgproto
# ==> Pouring xorgproto--2025.1.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/xorgproto/2025.1: 268 files, 4.2MB
# ==> Installing llama.cpp dependency: libxau
# ==> Pouring libxau--1.0.12.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libxau/1.0.12: 22 files, 153.8KB
# ==> Installing llama.cpp dependency: libxdmcp
# ==> Pouring libxdmcp--1.1.5.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libxdmcp/1.1.5: 13 files, 156.6KB
# ==> Installing llama.cpp dependency: libxcb
# ==> Pouring libxcb--1.17.0.x86_64_linux.bottle.1.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libxcb/1.17.0: 2,498 files, 7.3MB
# ==> Installing llama.cpp dependency: libx11
# ==> Pouring libx11--1.8.13.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libx11/1.8.13: 1,050 files, 8.5MB
# ==> Installing llama.cpp dependency: expat
# ==> Pouring expat--2.8.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/expat/2.8.0: 23 files, 922.2KB
# ==> Installing llama.cpp dependency: libffi
# ==> Pouring libffi--3.5.2.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libffi/3.5.2: 19 files, 835.8KB
# ==> Installing llama.cpp dependency: ncurses
# ==> Pouring ncurses--6.6.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/ncurses/6.6: 4,071 files, 11.7MB
# ==> Installing llama.cpp dependency: readline
# ==> Pouring readline--8.3.3.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/readline/8.3.3: 56 files, 3MB
# ==> Installing llama.cpp dependency: libxml2
# ==> Pouring libxml2--2.15.3.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/libxml2/2.15.3: 60 files, 2.3MB
# ==> Installing llama.cpp dependency: wayland
# ==> Pouring wayland--1.25.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/wayland/1.25.0: 40 files, 1MB
# ==> Installing llama.cpp dependency: vulkan-loader
# ==> Pouring vulkan-loader--1.4.341.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/vulkan-loader/1.4.341.0: 12 files, 742.6KB
# ==> Installing llama.cpp dependency: ggml
# ==> Pouring ggml--0.10.0.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/ggml/0.10.0: 49 files, 74.7MB
# ==> Installing llama.cpp dependency: ca-certificates
# ==> Pouring ca-certificates--2026-03-19.all.bottle.tar.gz
# Loaded 146 system certificates
# Loaded 15 Mozilla certificates
# ==> CA certificates have been bootstrapped from the system CA store at /etc/ssl/certs/ca-certificates.crt
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/ca-certificates/2026-03-19: 4 files, 253.4KB
# ==> Installing llama.cpp dependency: openssl@3
# ==> Pouring openssl@3--3.6.2.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/openssl@3/3.6.2: 7,637 files, 45MB
# ==> Installing llama.cpp
# ==> Pouring llama.cpp--8950.x86_64_linux.bottle.tar.gz
# 🍺  /home/linuxbrew/.linuxbrew/Cellar/llama.cpp/8950: 64 files, 26.9MB
# ==> Running `brew cleanup llama.cpp`...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).

# %%
# !llama-cli -hf ggml-org/gemma-3-1b-it-GGUF
# Out:
# load_backend: loaded BLAS backend from /home/linuxbrew/.linuxbrew/Cellar/ggml/0.10.0/libexec/libggml-blas.so
# load_backend: loaded CPU backend from /home/linuxbrew/.linuxbrew/Cellar/ggml/0.10.0/libexec/libggml-cpu-haswell.so
#
# Downloading gemma-3-1b-it-Q4_K_M.gguf ────────────────────────────── 100%
# |
#
#
# ▄▄ ▄▄
# ██ ██
# ██ ██  ▀▀█▄ ███▄███▄  ▀▀█▄    ▄████ ████▄ ████▄
# ██ ██ ▄█▀██ ██ ██ ██ ▄█▀██    ██    ██ ██ ██ ██
# ██ ██ ▀█▄██ ██ ██ ██ ▀█▄██ ██ ▀████ ████▀ ████▀
#                                     ██    ██
#                                     ▀▀    ▀▀
#
# build      : b8950-4414c04b9
# model      : ggml-org/gemma-3-1b-it-GGUF
# modalities : text
#
# available commands:
#   /exit or Ctrl+C     stop or exit
#   /regen              regenerate the last response
#   /clear              clear the chat history
#   /read <file>        add a text file
#   /glob <pattern>     add text files using globbing pattern
#
#
# > hello
#
# Hello there! How's your day going so far? 😊
#
# Is there anything you'd like to chat about or anything I can help you with?
#
# [ Prompt: 14.2 t/s | Generation: 11.0 t/s ]
#
# >
